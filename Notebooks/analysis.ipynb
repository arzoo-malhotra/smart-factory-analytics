# %% [markdown]
# # Analysis Notebook
# Initial analysis notebook for smart factory AI analytics.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load and analyze your data here
